# %% [markdown]
# # Problem 3
# ### 1)

# %%
yr2sec = 3.15e7

tau = 1e6*yr2sec # s
delrho = 450 # kg/m^3
g = 9.8 # m/s^2
b = 3e3 # m

vis = tau*delrho*g*b/13.04
print(vis)
# Out:
# 3.1958972392638042e+19

# %% [markdown]
# ### 2)

# %%
delrho = 100 # kg/m^3
g = 9.8 # m/s^2
b = 6.6e5 # m
visc = 1e21 # Pas

tau = 13.04*visc / delrho / g / b
print(tau/yr2sec, 'years')
# Out:
# 640025.1298210481 years

# %% [markdown]
# # Problem 4
# ### 1)

# %%
# Mercury
visc = 1e21 # Pa*s
k = 4 # W/m/K
kappa = 1e-6 # m^2/s
a = 3e-5 # /K
g = 3.7 # m/s^2
rho = 5440 # kg/m^3
H = 9e-12 # W/kg
b = 5.5e5 # m

Ra = (a * rho**2 * g * H * b**5)/(k * visc * kappa)
print('Ra of Mercury = ',Ra)
# Out:
# Ra of Mercury =  371977.562088

# %%
# Venus
visc = 1e21 # Pa*s
k = 4 # W/m/K
kappa = 1e-6 # m^2/s
a = 3e-5 # /K
g = 8.87 # m/s^2
rho = 2800 # kg/m^3
H = 9e-12 # W/kg
b = 2.88e6 # m

Ra = (a * rho**2 * g * H * b**5)/(k * visc * kappa)
print('Ra of Venus = ',Ra)
# Out:
# Ra of Venus =  930049137.0781213

# %%
# Mars
visc = 1e21 # Pa*s
k = 4 # W/m/K
kappa = 1e-6 # m^2/s
a = 3e-5 # /K
g = 3.7 # m/s^2
rho = 3950 # kg/m^3
H = 9e-12 # W/kg
b = 2e6 # m

Ra = (a * rho**2 * g * H * b**5)/(k * visc * kappa)
print('Ra of Mars = ',Ra)
# Out:
# Ra of Mars =  124695180.00000001

# %%
# Moon
visc = 1e21 # Pa*s
k = 4 # W/m/K
kappa = 1e-6 # m^2/s
a = 3e-5 # /K
g = 1.62 # m/s^2
rho = 3340 # kg/m^3
H = 9e-12 # W/kg
b = 4e5 # m

Ra = (a * rho**2 * g * H * b**5)/(k * visc * kappa)
print('Ra of Moon = ',Ra)
# Out:
# Ra of Moon =  12491.416166400002

# %% [markdown]
# ### 2)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
value = np.linspace(0.1, 10.0, 100) # value = 2*pi*b/lambda
Ra = (np.pi**2 + value**2)**3 / value**2
plt.plot(value, Ra)
plt.ylim(0,4500)
plt.xlabel('$2 \pi b / \lambda$')
plt.ylabel('Ra')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'Ra')

# %% [markdown]
# When Ra=2000, the corresponding dimensionless wave numbers(2*pi*b/lambda) are 0.8 and 5.4.
#
# Since
# $ \lambda = \frac{2 \pi b}{0.8} $ ,
#
# The exact minimum and maximum values of the wavelength are 1.16b and 7.85b

# %% [markdown]
# # Problem 5

# %% [markdown]
# When n = 1,
#
# $
# \begin{equation}
# 2 \mu \dot{\epsilon} = \rho g w \\
# 2 \mu \frac{\dot{w}}{L} = \rho gw \\
# \dot{w} = \frac{L \rho g}{2 \mu}
# \end{equation}
# $
#
# The solution is,
# $w(t) = w(0) \exp{\frac{L \rho g}{2 \mu}t} \: $

# %% [markdown]
# When $n \neq 1$,
#
# $
# \begin{equation}
# \big( \frac{1}{B} \dot{\epsilon} \big)^{\frac{1}{n}} = \rho g w \\
# \big( \frac{\dot{w}}{BL} \big)^{\frac{1}{n}} = \rho g w \\
# \dot{w} = \rho^{n} g^{n} w^{n} BL
# \end{equation}
# $
#
# The solution for $n = 2$ is given as
# $w(t) = - \frac{2}{t^2 + w(0)}$
#
# The solution for $n = 3$ is given as
# $w(t) = - \frac{1}{\sqrt{w(0) - t^2}}$

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
datat = [0, 120, 520, 1320, 3320, 9320]
dataw = [446, 437, 385, 331, 261, 180]

t = np.linspace(1, 10000)

rho = 3300 # kg/m^3
mu = 1.e21 # Pas
g = 10 # m/s^2
B = 6.6e5 # m
L = 7e5 # m
w0 = 446 # m

w1 = w0 * np.exp(L*rho*g*t/(2*mu))
w2 = - 2/(t**2 + w0)
#w3 = - 1/np.sqrt(np.sqrt(w0 - t**2))

# %%
plt.plot(t, w1, color = 'blue')
plt.plot(t, w2, color = 'red')
plt.plot(datat, dataw, 'o', color = 'k')
#plt.plot(t, w3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Why do I always screw up plotting?... :'‑(
